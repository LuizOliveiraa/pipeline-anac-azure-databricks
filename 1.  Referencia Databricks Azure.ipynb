# %% [markdown]
# ##########TESTE #############
#
# TREINAMENTO UDEMY: Databricks Developer Spark,SQL,Python Para Análise de Dados
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/40468008?start=30#overview
#
# *******************************************************************************************************************************************************
# 25/09/2025 - CONCLUÍDO: SEÇÃO 1: INTRODUÇÃO - 3. Material Para Download
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/50843339#overview
#
# -----------------------------------------------------------------------------
# 26/09/2025 - CONCLUÍDO: SEÇÃO 3: Primeiras Configurações e Cadastros - 14. Conhecendo os Menus Databricks
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/40468108#overview
#
# -----------------------------------------------------------------------------
# 30/09/2025 - CONCLUÍDO: SEÇÃO 4: Primeiros Comandos Manipulação de Arquivos - 20. Importando Scripts e Notbooks para o Databricks
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/40535077#overview
#
# https://dbc-9d3fe614-2ab9.cloud.databricks.com/browse/folders/634322487883642?o=146275463833389
#
#
# -----------------------------------------------------------------------------
# 01/10/2025 - CONCLUÍDO: SEÇÃO 4: Primeiros Comandos Manipulação de Arquivos - 21. Manipulação de Dados Databricks dbutils
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/40535083#overview
#
# -----------------------------------------------------------------------------
# 02/10/2025 - CONCLUÍDO: SEÇÃO 4: Primeiros Comandos Manipulação de Arquivos - 22. Manipulando DataFrame Databricks
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/40535089#overview
#
# -----------------------------------------------------------------------------
# 03/10/2025 - CONCLUÍDO: SEÇÃO 4: Primeiros Comandos Manipulação de Arquivos - 23. Localizando Dados Publicos Para Treino databricks-datasets + kaggle.com
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/40535091#overview
#
# -----------------------------------------------------------------------------
# 05/10/2025 - CONCLUÍDO: SEÇÃO 5: Comandos SQL - 25. Criando Banco de Dados e importando Tabelas para Databricks
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/40535097#overview
#
# -----------------------------------------------------------------------------
# 06/10/2025 - CONCLUÍDO: SEÇÃO 5: Comandos SQL - 27. Salvando Dados em diferentes Formatos
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/40535099#overview
#
# -----------------------------------------------------------------------------
# 08/10/2025 - CONCLUÍDO: SEÇÃO 7: Filtros Avançados de Dados - 37. Filtros de textos no Databricks (Método Filter)
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/40678790#overview
#
# -----------------------------------------------------------------------------
# 13/10/2025 - CONCLUÍDO: SEÇÃO 7: Filtros Avançados de Dados - 46. Filtro de Valores
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/40678812#overview
#
#            - CONCLUÍDO: SEÇÃO 8: Manipulação de Colunas - 48. Selecionando apenas algumas colunas do Dataframe
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/40830412#overview
#
# -----------------------------------------------------------------------------
# 21/10/2025 - CONCLUÍDO: SEÇÃO 8: Manipulação de Colunas - 51. Criando Coluna Condicional de Valor
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/40830422#overview
#
# -----------------------------------------------------------------------------
# 22/10/2025  - CONCLUÍDO: SEÇÃO 9: Conversão de Dados - 58. Arredondamento de Numeros
#
# - CONCLUÍDO: SEÇÃO 8: Manipulação de Colunas - 54. Comando Sql Criando Coluna condicional entre Valores
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/40830432#overview
#
# -----------------------------------------------------------------------------
# 28/10/2025  - CONCLUÍDO: SEÇÃO 10: Trabalhando com Data e Hora - 59. Trabalhando com Datas DataFrame
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/40840660#overview
#
# -----------------------------------------------------------------------------
# 29/10/2025  - CONCLUÍDO: SEÇÃO 10: Trabalhando com Data e Hora - 62. Trabalhando com Datas avançadas em SQL
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/41005342#overview
#
# -----------------------------------------------------------------------------
# 30/10/2025  - CONCLUÍDO: SEÇÃO 11: Tratando Dados Nulos - 66. Tratando nulos Databricks em SQL
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/41005356#overview
#
# -----------------------------------------------------------------------------
# 02/11/2025  - CONCLUÍDO: SEÇÃO 13: Databricks Delta Lake Transações e controle de Dados - 73. Otimização de Dados Funções avançadas
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/41005414#overview
#
# -----------------------------------------------------------------------------
# 06/11/2025  - CONCLUÍDO: SEÇÃO 14: Conta na Microsoft Azure Cloud  - 79. Arquitetura Básica do Projeto Azure
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/41360058#overview
#
# -----------------------------------------------------------------------------
# 09/11/2025  - CONCLUÍDO: SEÇÃO 15: Github - 83. Como Instalar GitHub Descktop e GitBash
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/41360076#overview
#
# -----------------------------------------------------------------------------
# 09/11/2025  - CONCLUÍDO: SEÇÃO 15: Github - 84. Como importar e compartilhar arquivos no GitHub
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/41360078#overview
#
# -----------------------------------------------------------------------------
# 13/11/2025  - CONCLUÍDO: SEÇÃO 15: Github - 85. Criando Repositório e importando Arquivos via GitHub Descktop sem usar scripts
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/41360080#overview
#
# -----------------------------------------------------------------------------
# 17/11/2025  - CONCLUÍDO: SEÇÃO 15: Github - 87. Aprendendo comandos Básicos GitHub e GitBash
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/41360086#overview
#
# …or create a new repository on the command line
# echo "# comando" >> README.md
# git init
# git add README.md
# git commit -m "first commit"
# git branch -M main
# git remote add origin https://github.com/LuizOliveiraa/comando.git
# git push -u origin main
# …or push an existing repository from the command line
# git remote add origin https://github.com/LuizOliveiraa/comando.git
# git branch -M main
# git push -u origin main
#
# -----------------------------------------------------------------------------
# 18/11/2025  - CONCLUÍDO: SEÇÃO 16: Preparando Ambiente Azure - 89. Criando Conta de Armazenamento Gen2
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/41360096#overview
#
# -----------------------------------------------------------------------------
# 20/11/2025  - CONCLUÍDO: SEÇÃO 16: Preparando Ambiente Azure - 90. Estruturando Data Lake Camadas de armazenamento Bronze, Prata e Ouro
# https://www.udemy.com/course/databricks-developer-sql-python-para-analise-de-dados/learn/lecture/41360098#overview

# %% [markdown]
# # Databricks notebook source
# # MAGIC %md
# # MAGIC
# # MAGIC ######Referecia Databicks Azure
# # MAGIC
# # MAGIC o que é lakehouse:
# # MAGIC https://learn.microsoft.com/pt-br/azure/databricks/lakehouse/
# # MAGIC
# # MAGIC
# # MAGIC O que é arquitetura medallion do Lakehouse?
# # MAGIC https://learn.microsoft.com/pt-br/azure/databricks/lakehouse/medallion
# # MAGIC
# # MAGIC
# # MAGIC Pipelines de processamento de ingestão, ETL e fluxo com o Azure Databricks e o Delta Lake
# # MAGIC https://learn.microsoft.com/pt-br/azure/architecture/solution-ideas/articles/ingest-etl-stream-with-adb
# # MAGIC
# # MAGIC Grupos de recursos do Azure
# # MAGIC https://learn.microsoft.com/pt-br/azure/azure-resource-manager/management/manage-resource-groups-portal
# # MAGIC
# # MAGIC
# # MAGIC Introdução ao Azure Data Lake Storage Gen2
# # MAGIC https://learn.microsoft.com/pt-br/azure/storage/blobs/data-lake-storage-introduction
# # MAGIC
# # MAGIC
# # MAGIC Autenticação e autorização no Serviço
# # MAGIC https://learn.microsoft.com/pt-br/azure/app-service/overview-authentication-authorization
# # MAGIC
# # MAGIC
# # MAGIC O que é a gestão de identidades e acessos (IAM)?
# # MAGIC https://learn.microsoft.com/pt-br/azure/active-directory/fundamentals/introduction-identity-access-management
# # MAGIC
# # MAGIC ACLs (Listas de controle de acesso) no Azure Data Lake Storage Gen2
# # MAGIC https://learn.microsoft.com/pt-br/azure/storage/blobs/data-lake-storage-access-control
# # MAGIC
# # MAGIC Gerenciador de Armazenamento do Microsoft Azure
# # MAGIC https://azure.microsoft.com/pt-br/products/storage/storage-explorer
# # MAGIC
# # MAGIC Runtimes do Azure Synapse
# # MAGIC https://learn.microsoft.com/pt-br/azure/synapse-analytics/spark/apache-spark-version-support
# # MAGIC
# # MAGIC Runtime do Synapse para ciclo de vida e suporte do Apache Spark
# # MAGIC https://learn.microsoft.com/pt-br/azure/synapse-analytics/spark/runtime-for-apache-spark-lifecycle-and-supportability
# # MAGIC
# # MAGIC
# # MAGIC Valor Cluster
# # MAGIC https://azure.microsoft.com/en-gb/pricing/details/databricks/
# # MAGIC
# # MAGIC
# # MAGIC
